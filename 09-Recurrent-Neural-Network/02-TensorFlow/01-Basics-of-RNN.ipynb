# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Creating Data

# %%
x = np.linspace(0, 50, 501)

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
df = pd.DataFrame(data=y, index=x, columns=['Sine'])
df
# Out:
#           Sine
# 0.0   0.000000
# 0.1   0.099833
# 0.2   0.198669
# 0.3   0.295520
# 0.4   0.389418
# ...        ...
# 49.6 -0.617439
# 49.7 -0.535823
# 49.8 -0.448854
# 49.9 -0.357400
# 50.0 -0.262375
#
# [501 rows x 1 columns]

# %% [markdown]
# ## Train Test Split

# %%
len(df)
# Out:
# 501

# %%
test_percent = 0.1

# %%
len(df) * test_percent
# Out:
# 50.1

# %%
test_point = np.round(len(df) * test_percent)
test_point
# Out:
# 50.0

# %%
test_index = int(len(df) - test_point)
test_index
# Out:
# 451

# %%
train_set = df.iloc[:test_index]
test_set = df.iloc[test_index:]

# %%
len(test_set)
# Out:
# 50

# %% [markdown]
# ## Normalization

# %%
scaler = MinMaxScaler()

# %%
train_set_scaled = scaler.fit_transform(train_set)
test_set_scaled = scaler.transform(test_set)

# %% [markdown]
# ## Creating Batches

# %%
length = 50
batch_size = 1

# %%
generator = TimeseriesGenerator(
    data=train_set_scaled,
    targets=train_set_scaled,
    length=length,
    batch_size=batch_size
)

# %%
len(train_set_scaled)
# Out:
# 451

# %%
len(generator)
# Out:
# 401

# %%
X, y = generator[0]

# %%
X
# Out:
# array([[[4.99999116e-01],
#         [5.49916225e-01],
#         [5.99334579e-01],
#         [6.47760405e-01],
#         [6.94709850e-01],
#         [7.39713809e-01],
#         [7.82322618e-01],
#         [8.22110545e-01],
#         [8.58680040e-01],
#         [8.91665714e-01],
#         [9.20737985e-01],
#         [9.45606372e-01],
#         [9.66022399e-01],
#         [9.81782075e-01],
#         [9.92727935e-01],
#         [9.98750612e-01],
#         [9.99789928e-01],
#         [9.95835500e-01],
#         [9.86926839e-01],
#         [9.73152957e-01],
#         [9.54651478e-01],
#         [9.31607263e-01],
#         [9.04250562e-01],
#         [8.72854714e-01],
#         [8.37733417e-01],
#         [7.99237589e-01],
#         [7.57751870e-01],
#         [7.13690771e-01],
#         [6.67494535e-01],
#         [6.19624741e-01],
#         [5.70559686e-01],
#         [5.20789614e-01],
#         [4.70811810e-01],
#         [4.21125636e-01],
#         [3.72227539e-01],
#         [3.24606094e-01],
#         [2.78737119e-01],
#         [2.35078919e-01],
#         [1.94067715e-01],
#         [1.56113277e-01],
#         [1.21594831e-01],
#         [9.08572769e-02],
#         [6.42077324e-02],
#         [4.19124713e-02],
#         [2.41942605e-02],
#         [1.12301346e-02],
#         [3.14962674e-03],
#         [3.34747619e-05],
#         [1.91281421e-03],
#         [8.76886734e-03]]])

# %%
y
# Out:
# array([[0.02053313]])

# %%
train_set_scaled
# Out:
# array([[4.99999116e-01],
#        [5.49916225e-01],
#        [5.99334579e-01],
#        [6.47760405e-01],
#        [6.94709850e-01],
#        [7.39713809e-01],
#        [4.78764928e-01],
#        [4.28998936e-01],
#        [3.79942353e-01],
#        [3.32085339e-01],
#        [2.85906063e-01],
#        [2.41865934e-01],
#        [2.00404987e-01],
#        [1.61937485e-01],
#        [1.26847783e-01],
#        [9.54864865e-02],
#        [6.81669460e-02],
#        [4.51621298e-02],
#        [2.67018944e-02],
#        [1.29706884e-02],
#        [4.10570950e-03],
#        [1.95533568e-04],
#        [1.27922981e-03],
#        [7.34597031e-03],
#        [1.83351382e-02],
#        [3.41369333e-02],
#        [5.45934694e-02],
#        [7.95003514e-02],
#        [1.08608718e-01],
#        [1.41627728e-01],
#        [1.78227467e-01],
#        [2.18042242e-01],
#        [2.60674236e-01],
#        [3.05697486e-01],
#        [3.52662133e-01],
#        [4.01098922e-01],
#        [4.50523890e-01],
#        [5.00443198e-01],
#        [5.50358069e-01],
#        [5.99769769e-01],
#        [6.48184595e-01],
#        [6.95118799e-01],
#        [7.40103433e-01],
#        [7.82689024e-01],
#        [8.22450070e-01],
#        [8.58989293e-01],
#        [8.91941605e-01],
#        [9.20977757e-01],
#        [9.45807630e-01],
#        [9.66183132e-01],
#        [9.81900676e-01],
#        [9.92803220e-01],
#        [9.98781828e-01],
#        [9.99776764e-01],
#        [9.95778087e-01],
#        [9.86825751e-01],
#        [9.73009203e-01],
#        [9.54466495e-01],
#        [9.31382900e-01],
#        [9.03989060e-01],
#        [8.72558686e-01],
#        [8.37405820e-01],
#        [7.98881698e-01],
#        [7.57371240e-01],
#        [7.13289205e-01],
#        [6.67076045e-01],
#        [6.19193508e-01],
#        [5.70120021e-01],
#        [5.20345908e-01],
#        [4.70368497e-01],
#        [4.20687145e-01],
#        [3.71798252e-01],
#        [3.24190300e-01],
#        [2.78338972e-01],
#        [2.34702398e-01],
#        [1.93716581e-01],
#        [1.55791039e-01],
#        [1.21304709e-01],
#        [9.06021693e-02],
#        [6.39901882e-02],
#        [4.17346643e-02],
#        [2.40579672e-02],
#        [1.11367167e-02],
#        [3.10001778e-03],
#        [2.81703720e-05],
#        [1.95186738e-03],
#        [8.85188786e-03],
#        [2.06592891e-02],
#        [3.72560954e-02],
#        [5.84764771e-02],
#        [8.41084070e-02],
#        [1.13895779e-01],
#        [1.47540969e-01],
#        [1.84707803e-01],
#        [2.25024924e-01],
#        [2.68089497e-01],
#        [3.13471233e-01],
#        [3.60716695e-01],
#        [4.09353821e-01],
#        [4.58896644e-01],
#        [5.08850150e-01],
#        [5.58715219e-01],
#        [6.07993616e-01],
#        [6.56192968e-01],
#        [7.02831682e-01],
#        [7.47443761e-01],
#        [7.89583454e-01],
#        [8.28829716e-01],
#        [8.64790412e-01],
#        [8.97106234e-01],
#        [9.25454293e-01]])

# %% [markdown]
# ## Creating the Model

# %%
num_of_features = 1

# %%
model = Sequential()

model.add(SimpleRNN(units=50 ,input_shape=(length, num_of_features)))
model.add(Dense(units=1))

model.compile(
    optimizer='adam',
    loss='mse'
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 50)             │         2,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,651 (10.36 KB)
#  Trainable params: 2,651 (10.36 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training the Model

# %%
model.fit(
    generator,
    epochs=5
)
# Out:
# Epoch 1/5
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0141
# Epoch 2/5
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.4480e-05
# Epoch 3/5
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.6904e-05
# Epoch 4/5
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.6233e-04
# Epoch 5/5
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.4656e-05

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Evaluation on Test Data

# %%
first_eval_batch = train_set_scaled[-length:]
first_eval_batch = first_eval_batch.reshape((1, length, num_of_features))

# %%
model.predict(first_eval_batch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# array([[0.9537328]], dtype=float32)

# %%
test_set_scaled[0]
# Out:
# array([0.94955134])

# %%
test_predictions = []

first_eval_batch = train_set_scaled[-length:]
current_batch = first_eval_batch.reshape((1, length, num_of_features))

# %%
# first_eval_batch.reshape((1, length, num_of_features))

# %%
# predicted_value = [[99]]
# np.append(current_batch[:,1:,:], [[[99]]], axis=1)

# %%
for i in range(len(test_set)):
    current_prediction = model.predict(current_batch)[0]
    test_predictions.append(current_prediction)
    current_batch = np.append(current_batch[:,1:,:], [[current_prediction]], axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
test_predictions
# Out:
# [array([0.9537328], dtype=float32),
#  array([0.97426355], dtype=float32),
#  array([0.98942864], dtype=float32),
#  array([0.9990653], dtype=float32),
#  array([1.0055531], dtype=float32),
#  array([1.0078455], dtype=float32),
#  array([1.0042098], dtype=float32),
#  array([0.9945826], dtype=float32),
#  array([0.98002195], dtype=float32),
#  array([0.96183443], dtype=float32),
#  array([0.94059604], dtype=float32),
#  array([0.91431034], dtype=float32),
#  array([0.883017], dtype=float32),
#  array([0.8478999], dtype=float32),
#  array([0.81118786], dtype=float32),
#  array([0.77226794], dtype=float32),
#  array([0.7300593], dtype=float32),
#  array([0.68439823], dtype=float32),
#  array([0.63714075], dtype=float32),
#  array([0.5901146], dtype=float32),
#  array([0.54318273], dtype=float32),
#  array([0.49444634], dtype=float32),
#  array([0.44429758], dtype=float32),
#  array([0.3946489], dtype=float32),
#  array([0.3480267], dtype=float32),
#  array([0.3037836], dtype=float32),
#  array([0.2601713], dtype=float32),
#  array([0.21702112], dtype=float32),
#  array([0.17690176], dtype=float32),
#  array([0.14250478], dtype=float32),
#  array([0.11334313], dtype=float32),
#  array([0.08615378], dtype=float32),
#  array([0.06046046], dtype=float32),
#  array([0.03945022], dtype=float32),
#  array([0.02699618], dtype=float32),
#  array([0.02106532], dtype=float32),
#  array([0.0173166], dtype=float32),
#  array([0.01475569], dtype=float32),
#  array([0.01801109], dtype=float32),
#  array([0.0310706], dtype=float32),
#  array([0.05161966], dtype=float32),
#  array([0.0730902], dtype=float32),
#  array([0.09371977], dtype=float32),
#  array([0.11890238], dtype=float32),
#  array([0.15492818], dtype=float32),
#  array([0.1979699], dtype=float32),
#  array([0.23899467], dtype=float32),
#  array([0.27487803], dtype=float32),
#  array([0.31382647], dtype=float32),
#  array([0.36391327], dtype=float32)]

# %%
test_set_scaled
# Out:
# array([[9.49551344e-01],
#        [9.69156618e-01],
#        [9.84074225e-01],
#        [9.94155114e-01],
#        [9.99298559e-01],
#        [9.99453170e-01],
#        [9.94617400e-01],
#        [9.84839568e-01],
#        [9.70217371e-01],
#        [9.50896908e-01],
#        [9.27071224e-01],
#        [8.98978376e-01],
#        [8.66899060e-01],
#        [8.31153800e-01],
#        [7.92099752e-01],
#        [7.50127132e-01],
#        [7.05655314e-01],
#        [6.59128649e-01],
#        [6.11012013e-01],
#        [5.61786173e-01],
#        [5.11942978e-01],
#        [4.61980443e-01],
#        [4.12397778e-01],
#        [3.63690397e-01],
#        [3.16344967e-01],
#        [2.70834550e-01],
#        [2.27613868e-01],
#        [1.87114770e-01],
#        [1.49741909e-01],
#        [1.15868702e-01],
#        [8.58335998e-02],
#        [5.99367021e-02],
#        [3.84367625e-02],
#        [2.15486014e-02],
#        [9.44095974e-03],
#        [2.23481297e-03],
#        [2.16257798e-06],
#        [2.76531647e-03],
#        [1.04966661e-02],
#        [2.31189624e-02],
#        [4.05060876e-02],
#        [6.24843152e-02],
#        [8.88340461e-02],
#        [1.19292002e-01],
#        [1.53553858e-01],
#        [1.91277281e-01],
#        [2.32085350e-01],
#        [2.75570325e-01],
#        [3.21297718e-01],
#        [3.68810636e-01]])

# %%
true_predictions = scaler.inverse_transform(test_predictions)
true_predictions
# Out:
# array([[ 0.90746006],
#        [ 0.94852125],
#        [ 0.97885119],
#        [ 0.99812432],
#        [ 1.01109991],
#        [ 1.01568466],
#        [ 1.00841319],
#        [ 0.98915902],
#        [ 0.96003797],
#        [ 0.92366322],
#        [ 0.88118678],
#        [ 0.82861579],
#        [ 0.76602963],
#        [ 0.69579601],
#        [ 0.6223725 ],
#        [ 0.54453327],
#        [ 0.46011673],
#        [ 0.36879528],
#        [ 0.27428107],
#        [ 0.18022951],
#        [ 0.08636654],
#        [-0.01110547],
#        [-0.11140217],
#        [-0.21069872],
#        [-0.30394241],
#        [-0.39242789],
#        [-0.47965179],
#        [-0.56595144],
#        [-0.64618953],
#        [-0.71498293],
#        [-0.77330577],
#        [-0.82768404],
#        [-0.87907025],
#        [-0.9210904 ],
#        [-0.94599828],
#        [-0.95785991],
#        [-0.96535729],
#        [-0.97047907],
#        [-0.96396831],
#        [-0.93784951],
#        [-0.89675172],
#        [-0.85381099],
#        [-0.81255218],
#        [-0.76218736],
#        [-0.69013634],
#        [-0.60405359],
#        [-0.5220047 ],
#        [-0.45023857],
#        [-0.3723423 ],
#        [-0.27216951]])

# %%
test_set['Predictions'] = true_predictions
test_set.head()
# Out:
#           Sine  Predictions
# 45.1  0.899097     0.907460
# 45.2  0.938307     0.948521
# 45.3  0.968142     0.978851
# 45.4  0.988304     0.998124
# 45.5  0.998591     1.011100

# %%
test_set.plot(figsize=(12,8))
# Out:
# <Axes: >

# %% [markdown]
# ## Creating LSTM Model

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=2
)

# %%
length = 49
batch_size = 1

# %%
generator = TimeseriesGenerator(
    data=train_set_scaled,
    targets=train_set_scaled,
    length=length,
    batch_size=batch_size
)

validation_generator = TimeseriesGenerator(
    data=test_set_scaled,
    targets=test_set_scaled,
    length=length,
    batch_size=batch_size
)

# %%
num_of_features = 1

# %%
model = Sequential()

model.add(LSTM(units=50 ,input_shape=(length, num_of_features)))
model.add(Dense(units=1))

model.compile(
    optimizer='adam',
    loss='mse'
)

# %%
model.fit(
    generator,
    validation_data=validation_generator,
    epochs=20,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/20
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0670 - val_loss: 1.1636e-04
# Epoch 2/20
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.4562e-04 - val_loss: 6.3525e-06
# Epoch 3/20
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.6729e-04 - val_loss: 7.0162e-05
# Epoch 4/20
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.1309e-05 - val_loss: 1.0239e-04

# %%
test_predictions = []

first_eval_batch = train_set_scaled[-length:]
current_batch = first_eval_batch.reshape((1, length, num_of_features))

for i in range(len(test_set)):
    current_prediction = model.predict(current_batch)[0]
    test_predictions.append(current_prediction)
    current_batch = np.append(current_batch[:,1:,:], [[current_prediction]], axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
true_predictions = scaler.inverse_transform(test_predictions)
test_set['LSTM Predictions'] = true_predictions
test_set.plot(figsize=(12,8))
# Out:
# <Axes: >

# %% [markdown]
# ## Forecasting into Future

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
generator = TimeseriesGenerator(
    data=scaled_full_data,
    targets=scaled_full_data,
    length=length,
    batch_size=batch_size
)

# %%
model = Sequential()

model.add(LSTM(units=50 ,input_shape=(length, num_of_features)))
model.add(Dense(units=1))

model.compile(
    optimizer='adam',
    loss='mse'
)

# %%
model.fit(
    generator,
    epochs=6,
)
# Out:
# Epoch 1/6
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0687
# Epoch 2/6
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.5649e-04
# Epoch 3/6
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.8804e-04
# Epoch 4/6
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.3996e-05
# Epoch 5/6
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4.4474e-05
# Epoch 6/6
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.2095e-04

# %%
forecast = []

first_eval_batch = train_set_scaled[-length:]
current_batch = first_eval_batch.reshape((1, length, num_of_features))

for i in range(25):
    current_prediction = model.predict(current_batch)[0]
    forecast.append(current_prediction)
    current_batch = np.append(current_batch[:,1:,:], [[current_prediction]], axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
forecast = full_scaler.inverse_transform(forecast)
forecast
# Out:
# array([[ 0.88103587],
#        [ 0.91522255],
#        [ 0.93900783],
#        [ 0.95227775],
#        [ 0.95504743],
#        [ 0.94738734],
#        [ 0.92943826],
#        [ 0.90141191],
#        [ 0.86359783],
#        [ 0.81636499],
#        [ 0.76016446],
#        [ 0.69553149],
#        [ 0.62308656],
#        [ 0.54353955],
#        [ 0.45768559],
#        [ 0.36640753],
#        [ 0.27067263],
#        [ 0.17152158],
#        [ 0.07005931],
#        [-0.03256476],
#        [-0.13517881],
#        [-0.23661855],
#        [-0.33575345],
#        [-0.43151589],
#        [-0.52291977]])

# %%
25 * 0.1
# Out:
# 2.5

# %%
forecast_index = np.arange(50.1, 52.6, step=0.1)

# %%
len(forecast_index)
# Out:
# 25

# %%
len(forecast)
# Out:
# 25

# %%
plt.plot(df.index, df['Sine'])
plt.plot(forecast_index, forecast)
